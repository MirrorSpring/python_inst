# %%
from mygan import MyGAN
import glob

mg=MyGAN(glob.glob('../Data/sexophone_edge/*.jpg'),100,100,5,channel=3)
mg.train(show_freq=100)
# Out:
# 1/1 [==============================] - 0s 399ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3792\2273740073.py in <module>
#       3
#       4 mg=MyGAN(glob.glob('../Data/sexophone_edge/*.jpg'),100,100,5,channel=3)
# ----> 5 mg.train(show_freq=100)
#
# c:\Users\dbtmd\Desktop\program\instrument\Python\Note\mygan.py in train(self, epochs, show_freq)
#     170         for epoch in range(epochs):
#     171             for image_batch in self.batch_data:
# --> 172                 self.train_step(image_batch)
#     173             if epoch%show_freq==0:
#     174                 self.show_generated_images(self.total_epochs)
#
# c:\Users\dbtmd\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
# ...

# %%
from mygan import MyGAN
import glob

mg=MyGAN(glob.glob('../Data/sexophone_edge/*.jpg'),100,100,5,channel=3)
mg.discriminator.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_2 (Conv2D)           (None, 50, 50, 200)       15200
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 50, 50, 200)       0
#
#  dropout_2 (Dropout)         (None, 50, 50, 200)       0
#
#  conv2d_3 (Conv2D)           (None, 25, 25, 400)       2000400
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 25, 25, 400)       0
#
#  flatten_1 (Flatten)         (None, 250000)            0
#
#  dense_6 (Dense)             (None, 800)               200000800
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 800)               0
#
#  dropout_3 (Dropout)         (None, 800)               0
#
#  dense_7 (Dense)             (None, 1)                 801
#
# ...
# Total params: 202,017,201
# Trainable params: 202,017,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow as tf
print(tf.__version__)
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# 2.10.0
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12173488793833902377
# xla_global_id: -1
# ]
